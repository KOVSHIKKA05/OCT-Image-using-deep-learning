# %%
"""
OCT Classification — FINAL FIXED VERSION
Works with Python 3.12 + latest TensorFlow/Keras
"""

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# =====================
# PATHS
# =====================
TRAIN_DIR = r"E:\2025-2026\OCT IMAGE\RetinalOCT_Dataset\RetinalOCT_Dataset\train"
VAL_DIR = r"E:\2025-2026\OCT IMAGE\RetinalOCT_Dataset\RetinalOCT_Dataset\val"
TEST_DIR = r"E:\2025-2026\OCT IMAGE\RetinalOCT_Dataset\RetinalOCT_Dataset\test"

IMG_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 10
MODEL_PATH = "oct_model.h5"

# =====================
# DATA GENERATORS
# =====================
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

val_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    color_mode="rgb"
)

val_data = val_gen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    color_mode="rgb"
)

test_data = val_gen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    color_mode="rgb"
)

CLASS_NAMES = list(train_data.class_indices.keys())
NUM_CLASSES = train_data.num_classes

print("Classes:", CLASS_NAMES)

# =====================
# EXPLICIT INPUT FIX ⭐
# =====================
input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, 3))

base_model = EfficientNetB0(
    weights="imagenet",
    include_top=False,
    input_tensor=input_tensor
)

# Freeze layers
for layer in base_model.layers:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
outputs = Dense(NUM_CLASSES, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=outputs)

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# =====================
# TRAINING
# =====================
callbacks = [
    EarlyStopping(patience=3, restore_best_weights=True),
    ModelCheckpoint(MODEL_PATH, save_best_only=True)
]

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =====================
# EVALUATION
# =====================
test_loss, test_acc = model.evaluate(test_data)
print("Test Accuracy:", test_acc)

preds = model.predict(test_data)
y_pred = np.argmax(preds, axis=1)
y_true = test_data.classes

print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_true, y_pred))

# =====================
# SAVE MODEL
# =====================
model.save(MODEL_PATH)
print("Model saved:", MODEL_PATH)

# =====================
# PREDICT FUNCTION
# =====================
def predict_image(img_path):
    from tensorflow.keras.preprocessing import image
    img = image.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    img = image.img_to_array(img)/255.0
    img = np.expand_dims(img, axis=0)
    pred = model.predict(img)
    print("Prediction:", CLASS_NAMES[np.argmax(pred)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 40
#      31 train_gen = ImageDataGenerator(
#      32     rescale=1./255,
#      33     rotation_range=10,
#      34     zoom_range=0.1,
#      35     horizontal_flip=True
#      36 )
#      38 val_gen = ImageDataGenerator(rescale=1./255)
# ---> 40 train_data = train_gen.flow_from_directory(
#      41     TRAIN_DIR,
#      42     target_size=(IMG_SIZE, IMG_SIZE),
#      43     batch_size=BATCH_SIZE,
#      44     class_mode="categorical",
#      45     color_mode="rgb"
#      46 )
#      48 val_data = val_gen.flow_from_directory(
#      49     VAL_DIR,
#      50     target_size=(IMG_SIZE, IMG_SIZE),
#    (...)     53     color_mode="rgb"
#      54 )
#      56 test_data = val_gen.flow_from_directory(
#      57     TEST_DIR,
#      58     target_size=(IMG_SIZE, IMG_SIZE),
#    (...)     62     color_mode="rgb"
# ...
